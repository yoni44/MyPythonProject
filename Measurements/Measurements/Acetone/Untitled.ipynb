# %%
pip install adafruit-blinka adafruit-circuitpython-bme680
# Out:
# ...
#    ---------------------------------------- 0.0/740.9 kB ? eta -:--:--
#    ---------------------------------------- 740.9/740.9 kB 8.3 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    ----------------------------------------  0/12 [pyserial]
#    --- ------------------------------------  1/12 [Adafruit-PlatformDetect]
#    --- ------------------------------------  1/12 [Adafruit-PlatformDetect]
#    ------ ---------------------------------  2/12 [pyusb]
#    ------ ---------------------------------  2/12 [pyusb]
#    ------ ---------------------------------  2/12 [pyusb]
# ...

# %%
import json
import csv

# %%
# Open and load the JSON data
with open("data.bmerawdata", "r") as f:
    data = json.load(f)

# Extract sensor samples
samples = data["samples"]

# Get the CSV headers
headers = samples[0].keys()

# Write to CSV
with open("output.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    writer.writerows(samples)

print("✅ Conversion complete! File saved as output.csv")
